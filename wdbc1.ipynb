# %%
summary(wdbc)
# Out:
#        id            diagnosis       c1               c2
#  Min.   :     8670   B:357     Min.   : 6.981   Min.   : 9.71
#  1st Qu.:   869218   M:212     1st Qu.:11.700   1st Qu.:16.17
#  Median :   906024             Median :13.370   Median :18.84
#  Mean   : 30371831             Mean   :14.127   Mean   :19.29
#  3rd Qu.:  8813129             3rd Qu.:15.780   3rd Qu.:21.80
#  Max.   :911320502             Max.   :28.110   Max.   :39.28
#        c3               c4               c5                c6
#  Min.   : 43.79   Min.   : 143.5   Min.   :0.05263   Min.   :0.01938
#  1st Qu.: 75.17   1st Qu.: 420.3   1st Qu.:0.08637   1st Qu.:0.06492
#  Median : 86.24   Median : 551.1   Median :0.09587   Median :0.09263
#  Mean   : 91.97   Mean   : 654.9   Mean   :0.09636   Mean   :0.10434
#  3rd Qu.:104.10   3rd Qu.: 782.7   3rd Qu.:0.10530   3rd Qu.:0.13040
#  Max.   :188.50   Max.   :2501.0   Max.   :0.16340   Max.   :0.34540
#        c7                c8                c9              c10
# ...

# %%
wdbc=read.table("wdbc.txt", header=T,sep=",")
attach(wdbc)
for (i in 3:32)
{
cat(paste("c",i-2,sep=""),"total mean=g", round(mean(wdbc[,i]),4),"\n")
cat("B mean=", round(mean(wdbc[diagnosis=="B",i]),4),"\n")
cat("M mean=", round(mean(wdbc[diagnosis=="M",i]),4),"\n")
}
# Out:
# The following objects are masked from wdbc (pos = 3):
#
#     c1, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c2, c20, c21,
#     c22, c23, c24, c25, c26, c27, c28, c29, c3, c30, c4, c5, c6, c7,
#     c8, c9, diagnosis, id
#
#
# The following objects are masked from wdbc (pos = 4):
#
#     c1, c10, c11, c12, c13, c14, c15, c16, c17, c18, c19, c2, c20, c21,
#     c22, c23, c24, c25, c26, c27, c28, c29, c3, c30, c4, c5, c6, c7,
#     c8, c9, diagnosis, id
# c1 total mean=g 14.1273
# B mean= 12.1465
# M mean= 17.4628
# c2 total mean=g 19.2896
# B mean= 17.9148
# M mean= 21.6049
# c3 total mean=g 91.969
# B mean= 78.0754
# M mean= 115.3654
# c4 total mean=g 654.8891
# B mean= 462.7902
# M mean= 978.3764
# c5 total mean=g 0.0964
# B mean= 0.0925
# M mean= 0.1029
# c6 total mean=g 0.1043
# B mean= 0.0801
# M mean= 0.1452
# c7 total mean=g 0.0888
# B mean= 0.0461
# M mean= 0.1608
# c8 total mean=g 0.0489
# B mean= 0.0257
# M mean= 0.088
# c9 total mean=g 0.1812
# B mean= 0.1742
# ...
