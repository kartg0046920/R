# %%
score=round(rnorm(100,70,10),1)
score
summary (score)
fivenum (score)
hist (score)
shapiro.test(score)
#install.packages("TSA")
library(TSA)
skewness(score)
kurtosis(score)
# Out:
#   [1] 71.9 85.1 81.9 69.0 58.6 65.2 68.8 77.1 69.4 75.0 81.1 60.7 69.9 62.3 67.7
#  [16] 75.6 91.7 71.0 65.4 74.3 68.9 78.5 86.6 71.6 70.1 61.0 58.9 64.1 56.6 75.2
#  [31] 58.8 59.5 59.0 67.1 67.5 76.5 83.4 86.9 81.5 62.6 64.4 59.7 79.9 61.9 59.4
#  [46] 63.6 77.7 54.2 66.3 76.9 83.7 69.1 68.9 72.7 67.9 71.4 78.6 82.8 87.3 74.6
#  [61] 76.3 80.1 78.6 82.1 77.5 54.7 56.6 63.3 84.7 69.5 68.3 50.2 76.4 88.9 74.4
#  [76] 62.5 72.3 79.8 60.2 81.1 68.2 76.1 63.3 63.3 54.3 76.4 42.5 60.7 71.7 78.6
#  [91] 68.0 65.1 76.7 59.1 70.9 75.7 72.2 65.9 74.1 69.4
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   42.50   63.30   70.00   70.47   76.95   91.70
# [1] 42.5 63.3 70.0 77.0 91.7
# 	Shapiro-Wilk normality test
#
# data:  score
# W = 0.99227, p-value = 0.8401
# Error in library(TSA): there is no package called ‘TSA’
# Traceback:
#
# 1. library(TSA)
# Plot with title “Histogram of score”

# %%
Q1 = quantile (score, 0.25)
Q1
ht = hist (score, breaks = c(min(score),quantile(score, 0.25), quantile(score, 0.5),quantile(score, 0.75),max(score)))
names ( ht)
ht $ breaks
ht $　counts
hist(score)
score = rnorm (500, 70, 10 )
hist(score)
# Out:
#  25%
# 63.3
# [1] "breaks"   "counts"   "density"  "mids"     "xname"    "equidist"
#         25%   50%   75%
# 42.50 63.30 70.00 76.95 91.70
# [1] 26 24 25 25
# Plot with title “Histogram of score”
# Plot with title “Histogram of score”
# Plot with title “Histogram of score”
