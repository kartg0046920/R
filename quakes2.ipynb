# %%
#lattice套組
install.packages("lattice")
head(quakes,10) #看資料前十筆
nrow(quakes) #看總共幾組
summary(quakes)
quakes$stations=factor(quakes$stations) #轉成因子變數
summary(quakes)
table(quakes$stations) #看有幾個工作站
# Out:
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)
#    lat    long   depth mag stations
# 1  -20.42 181.62 562   4.8 41
# 2  -20.62 181.03 650   4.2 15
# 3  -26.00 184.10  42   5.4 43
# 4  -17.97 181.66 626   4.1 19
# 5  -20.42 181.96 649   4.0 11
# 6  -19.68 184.31 195   4.0 12
# 7  -11.70 166.10  82   4.8 43
# 8  -28.11 181.93 194   4.4 15
# 9  -28.74 181.74 211   4.7 35
# 10 -17.47 179.59 622   4.3 19
# [1] 1000
#       lat              long           depth            mag          stations
#  Min.   :-38.59   Min.   :165.7   Min.   : 40.0   Min.   :4.00   14     : 39
#  1st Qu.:-23.47   1st Qu.:179.6   1st Qu.: 99.0   1st Qu.:4.30   17     : 38
#  Median :-20.30   Median :181.4   Median :247.0   Median :4.60   21     : 37
#  Mean   :-20.64   Mean   :179.5   Mean   :311.4   Mean   :4.62   16     : 35
#  3rd Qu.:-17.64   3rd Qu.:183.2   3rd Qu.:543.0   3rd Qu.:4.90   22     : 35
#  Max.   :-10.72   Max.   :188.1   Max.   :680.0   Max.   :6.40   23     : 35
# ...
