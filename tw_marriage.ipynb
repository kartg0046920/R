# %%
tw = read.table("tw_marriage.txt",header=T)
tw
tw $ area = factor ( tw $ area, levels = c ("北" , "中" , "南" , "東" , "外島" ) ) 
cat("unmarried:\n")

#table(unmarriaged~area, data=tw)
(xt = xtabs (tw [ , 4] ~ area + gender, data = tw))
round(prop.table(xt)*100,2)

(xt = xtabs (tw [ , 5] ~ area + gender, data = tw))
round(prop.table(xt)*100,2)

(xt = xtabs (tw [ , 6] ~ area + gender, data = tw))
round(prop.table(xt)*100,2)

(xt = xtabs (tw [ , 7] ~ area + gender, data = tw))
round(prop.table(xt)*100,2)
# Out:
#    city   gender area unmarried married divorced widowed
# 1  臺北縣 M      北   637368    818793  104489    25693
# 2  臺北縣 F      北   543174    827473  126557   121494
# 3  宜蘭縣 M      北    71035    107117   12307     5429
# 4  宜蘭縣 F      北    56004     98737   11399    22249
# 5  桃園縣 M      北   295943    427139   52584    13929
# 6  桃園縣 F      北   237851    422715   60684    61695
# 7  新竹縣 M      北    69957    119320   12243     5417
# 8  新竹縣 F      北    52765    111944   11788    18552
# 9  苗栗縣 M      北    85526    134653   14184     7680
# 10 苗栗縣 F      北    65136    119849   12211    25594
# 11 臺中縣 M      中   248357    344668   34468    15005
# 12 臺中縣 F      中   199040    337385   36092    55607
# 13 彰化縣 M      中   203853    311580   24876    15413
# 14 彰化縣 F      中   159841    288130   21760    57826
# 15 南投縣 M      中    81591    126201   14467     7707
# 16 南投縣 F      中    62353    113063   12712    26887
# 17 雲林縣 M      中   103481    184870   17622    11062
# ...
