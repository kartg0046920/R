# %%
attach(iris)
layout(matrix(c(2,4,1,3),2,2, byrow=T), widths=c(2,1), heights=c(1,2))
plot(Sepal.Length,Sepal.Width,main="Sepal Length-Width Scatter Graph")
hist(Sepal.Length,main="Sepal Length Histogram Graph")
hist(Sepal.Width,main="Sepal Width Histogram Graph")
plot(Species)


par(mai=c(0.5,0.5,0.5,0.5),mfrow=c(2,2))
lab=colnames(iris)
#Sepal.Length-->iris[,1]-->iris[,i]
for ( i in 1:4)
{
plot(Species,iris[,i],main=lab[i])
}


par(mai=c(0.5,0.5,0.5,0.5),mfrow=c(2,2))
plot(iris[Species=="setosa",2],iris[Species=="setosa",1],ylim=c(4,8),xlim=c(2,4))
plot(iris[Species=="versicolor",2],iris[Species=="versicolor",1],ylim=c(4,8),xlim=c(2,4))
plot(iris[Species=="virginica",2],iris[Species=="virginica",1],ylim=c(4,8),xlim=c(2,4))

coplot(Sepal.Length~Sepal.Width | Secies,rows=1)
# Out:
# The following objects are masked from iris (pos = 3):
#
#     Petal.Length, Petal.Width, Sepal.Length, Sepal.Width, Species
#
#
# The following objects are masked from iris (pos = 4):
#
#     Petal.Length, Petal.Width, Sepal.Length, Sepal.Width, Species
#
#
# The following objects are masked from iris (pos = 5):
#
#     Petal.Length, Petal.Width, Sepal.Length, Sepal.Width, Species
#
#
# The following objects are masked from iris (pos = 6):
#
#     Petal.Length, Petal.Width, Sepal.Length, Sepal.Width, Species
#
#
# The following objects are masked from iris (pos = 13):
#
#     Petal.Length, Petal.Width, Sepal.Length, Sepal.Width, Species
#
#
# The following objects are masked from iris (pos = 17):
#
#     Petal.Length, Petal.Width, Sepal.Length, Sepal.Width, Species
#
#
# The following objects are masked from iris (pos = 18):
#
#     Petal.Length, Petal.Width, Sepal.Length, Sepal.Width, Species
# Plot with title “Sepal Width Histogram Graph”
# ...
