# %%
# method 1
install.packages("arules")
library(arules)
beer=read.csv("beer.csv",header=T)
beer=as.matrix(beer)
rule=apriori(beer,parameter=list(supp=0.2,conf=0.8,maxlen=5))   #default 是0.1, 0.8, 10
inspect(rule)
summary(rule)
inspect(head(sort(rule,by="support"),10))
inspect(head(sort(rule,by="confidence"),10))
# Out:
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5     0.2      1
#  maxlen target   ext
#       5  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[6 item(s), 5 transaction(s)] done [0.00s].
# sorting and recoding items ... [6 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [31 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
#      lhs                    rhs      support confidence lift     count
# [1]  {}                  => {Milk}   0.8     0.8        1.000000 4
# [2]  {}                  => {Bread}  0.8     0.8        1.000000 4
# [3]  {}                  => {Diaper} 0.8     0.8        1.000000 4
# [4]  {Egg}               => {Beer}   0.2     1.0        1.666667 1
# [5]  {Egg}               => {Bread}  0.2     1.0        1.250000 1
# [6]  {Egg}               => {Diaper} 0.2     1.0        1.250000 1
# [7]  {Coke}              => {Milk}   0.4     1.0        1.250000 2
# [8]  {Coke}              => {Diaper} 0.4     1.0        1.250000 2
# [9]  {Beer}              => {Diaper} 0.6     1.0        1.250000 3
# [10] {Beer,Egg}          => {Bread}  0.2     1.0        1.250000 1
# [11] {Bread,Egg}         => {Beer}   0.2     1.0        1.666667 1
# [12] {Beer,Egg}          => {Diaper} 0.2     1.0        1.250000 1
# [13] {Diaper,Egg}        => {Beer}   0.2     1.0        1.666667 1
# [14] {Bread,Egg}         => {Diaper} 0.2     1.0        1.250000 1
# [15] {Diaper,Egg}        => {Bread}  0.2     1.0        1.250000 1
# [16] {Beer,Coke}         => {Milk}   0.2     1.0        1.250000 1
# [17] {Beer,Coke}         => {Diaper} 0.2     1.0        1.250000 1
# [18] {Bread,Coke}        => {Milk}   0.2     1.0        1.250000 1
# [19] {Milk,Coke}         => {Diaper} 0.4     1.0        1.250000 2
# [20] {Diaper,Coke}       => {Milk}   0.4     1.0        1.250000 2
# [21] {Bread,Coke}        => {Diaper} 0.2     1.0        1.250000 1
# [22] {Milk,Beer}         => {Diaper} 0.4     1.0        1.250000 2
# [23] {Bread,Beer}        => {Diaper} 0.4     1.0        1.250000 2
# [24] {Bread,Beer,Egg}    => {Diaper} 0.2     1.0        1.250000 1
# [25] {Diaper,Beer,Egg}   => {Bread}  0.2     1.0        1.250000 1
# [26] {Bread,Diaper,Egg}  => {Beer}   0.2     1.0        1.666667 1
# [27] {Milk,Beer,Coke}    => {Diaper} 0.2     1.0        1.250000 1
# [28] {Diaper,Beer,Coke}  => {Milk}   0.2     1.0        1.250000 1
# [29] {Bread,Milk,Coke}   => {Diaper} 0.2     1.0        1.250000 1
# [30] {Bread,Diaper,Coke} => {Milk}   0.2     1.0        1.250000 1
# [31] {Bread,Milk,Beer}   => {Diaper} 0.2     1.0        1.250000 1
# set of 31 rules
#
# rule length distribution (lhs + rhs):sizes
#  1  2  3  4
#  3  6 14  8
#
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   1.000   2.000   3.000   2.871   3.500   4.000
#
# summary of quality measures:
#     support         confidence          lift           count
#  Min.   :0.2000   Min.   :0.8000   Min.   :1.000   Min.   :1.000
#  1st Qu.:0.2000   1st Qu.:1.0000   1st Qu.:1.250   1st Qu.:1.000
#  Median :0.2000   Median :1.0000   Median :1.250   Median :1.000
#  Mean   :0.3097   Mean   :0.9806   Mean   :1.280   Mean   :1.548
#  3rd Qu.:0.4000   3rd Qu.:1.0000   3rd Qu.:1.250   3rd Qu.:2.000
#  Max.   :0.8000   Max.   :1.0000   Max.   :1.667   Max.   :4.000
#
# mining info:
#  data ntransactions support confidence
#  beer             5     0.2        0.8
#      lhs              rhs      support confidence lift count
# [1]  {}            => {Milk}   0.8     0.8        1.00 4
# [2]  {}            => {Bread}  0.8     0.8        1.00 4
# [3]  {}            => {Diaper} 0.8     0.8        1.00 4
# [4]  {Beer}        => {Diaper} 0.6     1.0        1.25 3
# [5]  {Coke}        => {Milk}   0.4     1.0        1.25 2
# [6]  {Coke}        => {Diaper} 0.4     1.0        1.25 2
# [7]  {Milk,Coke}   => {Diaper} 0.4     1.0        1.25 2
# [8]  {Diaper,Coke} => {Milk}   0.4     1.0        1.25 2
# [9]  {Milk,Beer}   => {Diaper} 0.4     1.0        1.25 2
# [10] {Bread,Beer}  => {Diaper} 0.4     1.0        1.25 2
#      lhs             rhs      support confidence lift     count
# [1]  {Egg}        => {Beer}   0.2     1          1.666667 1
# [2]  {Egg}        => {Bread}  0.2     1          1.250000 1
# [3]  {Egg}        => {Diaper} 0.2     1          1.250000 1
# [4]  {Coke}       => {Milk}   0.4     1          1.250000 2
# [5]  {Coke}       => {Diaper} 0.4     1          1.250000 2
# [6]  {Beer}       => {Diaper} 0.6     1          1.250000 3
# [7]  {Beer,Egg}   => {Bread}  0.2     1          1.250000 1
# [8]  {Bread,Egg}  => {Beer}   0.2     1          1.666667 1
# [9]  {Beer,Egg}   => {Diaper} 0.2     1          1.250000 1
# [10] {Diaper,Egg} => {Beer}   0.2     1          1.666667 1

# %%
# method 2
beer=read.transactions("beer.txt",sep=",")
beer2=as(beer,"transactions")
inspect(beer2)
rule=apriori(beer,parameter=list(supp=0.2,conf=0.8,maxlen=5))
inspect(head(sort(rule,by="support"),10))
# Out:
# Warning message in readLines(file, encoding = encoding):
# “incomplete final line found on 'beer.txt'”
#     items
# [1] {Bread,Milk}
# [2] {Beer,Bread,Diaper,Eggs}
# [3] {Beer,Coke,Diaper,Milk}
# [4] {Beer,Bread,Diaper,Milk}
# [5] {Bread,Coke,Diaper,Milk}
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5     0.2      1
#  maxlen target   ext
#       5  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 1
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[6 item(s), 5 transaction(s)] done [0.00s].
# sorting and recoding items ... [6 item(s)] done [0.00s].
# creating transaction tree ... done [0.00s].
# checking subsets of size 1 2 3 4 done [0.00s].
# writing ... [31 rule(s)] done [0.00s].
# creating S4 object  ... done [0.00s].
#      lhs              rhs      support confidence lift count
# [1]  {}            => {Milk}   0.8     0.8        1.00 4
# [2]  {}            => {Bread}  0.8     0.8        1.00 4
# [3]  {}            => {Diaper} 0.8     0.8        1.00 4
# [4]  {Beer}        => {Diaper} 0.6     1.0        1.25 3
# [5]  {Coke}        => {Milk}   0.4     1.0        1.25 2
# [6]  {Coke}        => {Diaper} 0.4     1.0        1.25 2
# [7]  {Coke,Milk}   => {Diaper} 0.4     1.0        1.25 2
# [8]  {Coke,Diaper} => {Milk}   0.4     1.0        1.25 2
# [9]  {Beer,Milk}   => {Diaper} 0.4     1.0        1.25 2
# [10] {Beer,Bread}  => {Diaper} 0.4     1.0        1.25 2
